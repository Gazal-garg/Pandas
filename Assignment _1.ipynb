# %%
import numpy as np
import pandas as pd
import io
#from google.colab 
#import files

# %%
#uploaded = files.upload()
df = pd.read_csv(r"C:\Users\Gazal\Documents\matches.csv")
df
# Out:
#       id  season       city        date                        team1  \
# 0      1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1      2    2017       Pune  2017-04-06               Mumbai Indians
# 2      3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3      4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4      5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 631  632    2016     Raipur  2016-05-22             Delhi Daredevils
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 633  634    2016      Delhi  2016-05-25          Sunrisers Hyderabad
# 634  635    2016      Delhi  2016-05-27                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
df.head(3)
# Out:
#    id  season       city  ...         umpire1    umpire2 umpire3
# 0   1    2017  Hyderabad  ...     AY Dandekar   NJ Llong     NaN
# 1   2    2017       Pune  ...  A Nand Kishore     S Ravi     NaN
# 2   3    2017     Rajkot  ...     Nitin Menon  CK Nandan     NaN
#
# [3 rows x 18 columns]

# %%
# Q1. Find the total number of matches played till now in IPL
print("Total no of matches played till now in IPL: ",len(df))
# Out:
# Total no of matches played till now in IPL:  636

# %%
# Q2. Create a new dataframe from df which will have all the alternate rows and columns from df starting from 0
new_df=df.iloc[::2 ,::2].copy()
new_df
# Out:
#       id           city                        team1  \
# 0      1      Hyderabad          Sunrisers Hyderabad
# 2      3         Rajkot                Gujarat Lions
# 4      5      Bangalore  Royal Challengers Bangalore
# 6      7         Mumbai        Kolkata Knight Riders
# 8      9           Pune             Delhi Daredevils
# ..   ...            ...                          ...
# 626  627         Kanpur        Kolkata Knight Riders
# 628  629  Visakhapatnam              Kings XI Punjab
# 630  631        Kolkata        Kolkata Knight Riders
# 632  633      Bangalore                Gujarat Lions
# 634  635          Delhi                Gujarat Lions
#
#                      toss_winner  result                       winner  \
# 0    Royal Challengers Bangalore  normal          Sunrisers Hyderabad
# 2          Kolkata Knight Riders  normal        Kolkata Knight Riders
# 4    Royal Challengers Bangalore  normal  Royal Challengers Bangalore
# ...

# %%
# Q3. Find the number of matches played in Mumbai in the period of 2013 and 2017
total=len(df[(df["city"]=="Mumbai") & ((df["season"]>=2013)&(df["season"]<=2017))])
print("Total no of matches played in Mumbai in the period of 2013 and 2017: ",total)
# Out:
# Total no of matches played in Mumbai in the period of 2013 and 2017:  38

# %%
# Q4. Find the number of matches where the margin of victory was greater than 30
mg=len(df[(df["win_by_runs"]>30)])
print("Total no of matches where the margin of victory was greater than 30: ",mg)
# Out:
# Total no of matches where the margin of victory was greater than 30:  103

# %%
# Q5. What percent times KKR decides to bat after winning the toss
a=len(df[(df["toss_winner"]=="Kolkata Knight Riders") & (df["toss_decision"]=="bat")])
b=len(df[df["toss_winner"]=="Kolkata Knight Riders"])
print("KKR chose to bat ",(a/b*100),"% times after winning the toss")
# Out:
# KKR chose to bat  38.46153846153847 % times after winning the toss
